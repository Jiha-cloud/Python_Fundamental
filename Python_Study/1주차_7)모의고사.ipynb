# %%
def solution(answers):
    idiot_1 = [1,2,3,4,5]
    idiot_2 = [2,1,2,3,2,4,2,5]
    idiot_3 = [3,3,1,1,2,2,4,4,5,5]
    idiot_1_score=0
    idiot_2_score=0
    idiot_3_score=0
    answer = []
    for i in range(len(answers)):    
        if answers[i] == idiot_1[i%5]:
            idiot_1_score += 1
    for i in range(len(answers)):    
        if answers[i] == idiot_2[i%8]:
            idiot_2_score += 1
    for i in range(len(answers)):    
        if answers[i] == idiot_3[i%10]:
            idiot_3_score += 1
            
    print(idiot_1_score,idiot_2_score,idiot_3_score)       
            
    if idiot_1_score > idiot_2_score:
        if idiot_1_score > idiot_3_score:
            answer = [1]
        elif idiot_1_score == idiot_3_score:
            answer = [1,3]
    elif idiot_1_score == idiot_2_score:
        if idiot_1_score > idiot_3_score:
            answer = [1,2]
        elif idiot_1_score == idiot_3_score:
            answer = [1,2,3]
            
    if idiot_1_score > idiot_3_score:
        if idiot_1_score > idiot_2_score:
            answer = [1]
        elif idiot_1_score == idiot_2_score:
            answer = [1,2]
    elif idiot_1_score == idiot_3_score:
        if idiot_1_score > idiot_2_score:
            answer = [1,3]
        elif idiot_1_score == idiot_2_score:
            answer = [1,2,3]
       
    if idiot_2_score > idiot_1_score:
        if idiot_2_score > idiot_3_score:
            answer = [2]
        elif idiot_2_score == idiot_1_score:
            answer = [1,2]
    elif idiot_2_score == idiot_1_score:
        if idiot_2_score > idiot_3_score:
            answer = [1,2]
        elif idiot_2_score == idiot_3_score:
            answer = [1,2,3]
    
    if idiot_2_score > idiot_3_score:
        if idiot_2_score > idiot_1_score:
            answer = [2]
        elif idiot_2_score == idiot_1_score:
            answer = [1,2]
    elif idiot_2_score == idiot_3_score:
        if idiot_2_score > idiot_1_score:
            answer = [2,3]
        elif idiot_2_score == idiot_1_score:
            answer = [1,2,3]
            
    if idiot_3_score > idiot_1_score:
        if idiot_3_score > idiot_2_score:
            answer = [3]
        elif idiot_3_score == idiot_2_score:
            answer = [2,3]
    elif idiot_3_score == idiot_1_score:
        if idiot_3_score > idiot_2_score:
            answer = [1,3]
        elif idiot_3_score == idiot_2_score:
            answer = [1,2,3]
    
    if idiot_3_score > idiot_2_score:
        if idiot_3_score > idiot_1_score:
            answer = [3]
        elif idiot_3_score == idiot_1_score:
            answer = [1,3]
    elif idiot_3_score == idiot_2_score:
        if idiot_3_score > idiot_1_score:
            answer = [2,3]
        elif idiot_3_score == idiot_1_score:
            answer = [1,2,3]
        
    return answer

print(solution([1,2,3,4,5]))
# Out:
# 5 0 0
# [1]
