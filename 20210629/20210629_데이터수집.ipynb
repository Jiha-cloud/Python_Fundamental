# %%
import requests
import urllib.request
from bs4 import BeautifulSoup as bs
import pandas as pd
from IPython.display import Image, HTML

# %%
headers = {'User-Agent':'Mozilla/5.0'}
url = 'https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1=001'
html = requests.get(url, headers = headers).text

# %%
html
# Out:
# '\r\n\r\n\r\n\r\n<!DOCTYPE HTML>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta http-equiv="refresh" content="600" />\r\n<meta name="viewport" content="width=1106" />\r\n\r\n    \r\n    \r\n        \r\n            \r\n            \r\n            \r\n            \r\n                \r\n                \r\n                \r\n                \r\n            \r\n            \r\n        \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="언론사별 속보 뉴스">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="http://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid=001">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png"/>\r\
# ...

# %%
soup = bs(html, 'html.parser')
type06 = soup.find('ul',{'class':'type06_headline'})
dl = type06.find_all('dl')

# %%
for item2 in dl:
    try:
        img = item2.find('dt',{'class':'photo'}).find('img')
        print('img = ',img['src'])
        print('--------------------------')
    except:
        print('No image')
# Out:
# img =  https://imgnews.pstatic.net/image/origin/091/2021/06/28/8824597.jpg?type=nf106_72
# --------------------------
# img =  https://imgnews.pstatic.net/image/origin/091/2021/06/28/8824596.jpg?type=nf106_72
# --------------------------
# img =  https://imgnews.pstatic.net/image/origin/091/2021/06/28/8824595.jpg?type=nf106_72
# --------------------------
# img =  https://imgnews.pstatic.net/image/origin/056/2021/06/28/11072090.jpg?type=nf106_72
# --------------------------
# No image
# img =  https://imgnews.pstatic.net/image/origin/021/2021/06/28/2476323.jpg?type=nf106_72
# --------------------------
# No image
# img =  https://imgnews.pstatic.net/image/origin/366/2021/06/28/739647.jpg?type=nf106_72
# --------------------------
# img =  https://imgnews.pstatic.net/image/origin/021/2021/06/28/2476322.jpg?type=nf106_72
# --------------------------
# img =  https://imgnews.pstatic.net/image/origin/021/2021/06/28/2476321.jpg?type=nf106_72
# --------------------------

# %%
for item2 in dl:
    link = item2.find('dt',{'class':''}).find('a')
    print(link['href'])
    print(link.text.replace('\t','').replace('\n','')[1:len(link.text)+1])
# Out:
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=091&aid=0008824597
#  CHINA COMMUNIST PARTY CENTENARY
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=091&aid=0008824596
#  CHINA COMMUNIST PARTY CENTENARY
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=091&aid=0008824595
#  CHINA COMMUNIST PARTY CENTENARY
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=056&aid=0011072090
#  ‘소급 대신 피해 지원’ 손실보상법 상임위 통과
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=469&aid=0000613863
#  [인사] 외교부 외
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=021&aid=0002476323
#  병영문화개선 민관군 합동위 출범…제도개선 흉내내기 시늉 우려도
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=374&aid=0000249050
#  서울시, 시내버스 운전기사에 백신 유급휴가제 도입
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=001&oid=366&aid=0000739647
#  SK바이오사이언스, 국내 첫 코로나19 백신 임상 3상 신청… “내년 상용화”
# ...

# %%
for item2 in dl:
    try:
        content = tem2.find('dd')
        print(content.text.replace('\t','').replace('\t','').split('...')[0])
    except:
        print('No image')
# Out:
# No image
# No image
# No image
# No image
# No image
# No image
# No image
# No image
# No image
# No image

# %%
img_url = []
article_url = []
article_title = []
article_text = []
total=[]
i=1
img_files=[]

type06 = soup.find('ul',{'class':'type06_headline'})
dl = type06.find_all('dl')

for item in dl:
    try:
        link = item.find('dt',{'class':'photo'})
        img = link.find('img')
        art_u = link.find('a')
        link2 = item.find('dd').find('span',{'class':'lede'})
        # img_file=urllib.request.urlretrieve(img['src'], 
        #                            'C:/Users/학생/Desktop/뉴스속보{}.jpg'.format(i))
        # img_files.append(img_file)
        
        i+=1
        
        img_url.append(img['src'])
        article_url.append(art_u['href'])
        article_title.append(img['alt'])
        article_text.append(link2.text)
    except:
        continue
        
# df = pd.DataFrame(['C:/Users/학생/Desktop/뉴스속보8.jpg'], columns = ['Image'])
# df
# urllib.request.urlretrieve(img['src'])
# Out:
#                            Image
# 0  C:/Users/학생/Desktop/뉴스속보8.jpg

# %%
article_emg = pd.DataFrame(data = list(zip(article_title,article_url,img_url,article_text)),
                                    columns=['기사제목','기사링크','이미지링크','기사본문'])

# article_emg = pd.DataFrame({'기사제목':article_title,'기사링크':article_url,
#                           '이미지링크':img_url,'기사본문':article_text})

pd.set_option('display.max.colwidth', 60)
article_emg
# Out:
#                                                   기사제목  \
# 0                          USA BASKETBALL NBA PLAYOFFS
# 1                          USA BASKETBALL NBA PLAYOFFS
# 2                                  Philippines Duterte
# 3                          USA BASKETBALL NBA PLAYOFFS
# 4                        DL이앤씨, 업계 첫 민간 안전체험교육장 인정서 취득
# 5                             서울 고덕동 고덕아남 84㎡ 13억원에 거래
# 6              [속보] 윤석열 "정권교체 반드시 해내야…안되면 부패 카르텔 판칠 것"
# 7  권수정 서울시의원 “서울의료원 정규직 전환, 이준석식 ‘공정’ 잣대에 필수노동자들은 피눈물”
#
#                                                           기사링크  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# 5  https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&si...
# ...

# %%
article_emg.to_csv('C:/Users/학생/Desktop/네이버속보.csv',index=False,encoding='utf-8-sig')
